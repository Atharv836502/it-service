# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\it services\\IT Services\\customers-10000.csv")

# %%
df.head()
# Out:
#    Index      Customer Id First Name  Last Name                   Company  \
# 0      1  EB54EF1154C3A78    Heather   Callahan              Mosley-David
# 1      2  10dAcafEBbA5FcA   Kristina    Ferrell  Horn, Shepard and Watson
# 2      3  67DAB15Ebe4BE4a     Briana   Andersen               Irwin-Oneal
# 3      4  6d350C5E5eDB4EE      Patty      Ponce          Richardson Group
# 4      5  5820deAdCF23EFe   Kathleen  Mccormick              Carson-Burch
#
#                City                   Country                Phone 1  \
# 0  Lake Jeffborough                    Norway           043-797-5229
# 1        Aaronville                   Andorra           932-062-1802
# 2       East Jordan                     Nepal             8352752061
# 3  East Kristintown  Northern Mariana Islands           302.398.3833
# 4       Andresmouth                     Macao  001-184-153-9683x1497
#
#               Phone 2                             Email Subscription Date  \
# ...

# %%
df.tail(7)
# Out:
#       Index      Customer Id First Name   Last Name            Company  \
# 9993   9994  5B8Ffc59EeBd87D    Bernard        Wolf         Huynh-Best
# 9994   9995  D7E40cCBde64d59        Kim       Yoder  Carpenter-Fleming
# 9995   9996  DD0caa06ebf217c     Meghan       Cline     Richardson LLC
# 9996   9997  C1C62ff90D0AfED   Jeremiah        Pena        Hodge-Nixon
# 9997   9998  2EfAa6Fe435A7DA      Peggy         Key           Vang LLC
# 9998   9999  5dB06C3Fab5CCCb       Evan    Humphrey          Gould Ltd
# 9999  10000  9903e8fF4D8Ff0F    Melissa  Montgomery       Burns-Holden
#
#                    City                       Country                Phone 1  \
# 9993  Port Barryborough                        Bhutan      977.287.5016x4827
# 9994  Lake Lawrenceview                       Armenia      667.966.2755x2648
# 9995         Petersport                 Cote d'Ivoire   001-270-136-4738x419
# 9996         Briggsport                       Namibia   +1-531-494-7645x4844
# ...

# %%
df.tail()
# Out:
#       Index      Customer Id First Name   Last Name         Company  \
# 9995   9996  DD0caa06ebf217c     Meghan       Cline  Richardson LLC
# 9996   9997  C1C62ff90D0AfED   Jeremiah        Pena     Hodge-Nixon
# 9997   9998  2EfAa6Fe435A7DA      Peggy         Key        Vang LLC
# 9998   9999  5dB06C3Fab5CCCb       Evan    Humphrey       Gould Ltd
# 9999  10000  9903e8fF4D8Ff0F    Melissa  Montgomery    Burns-Holden
#
#                 City                       Country                Phone 1  \
# 9995      Petersport                 Cote d'Ivoire   001-270-136-4738x419
# 9996      Briggsport                       Namibia   +1-531-494-7645x4844
# 9997  West Joyceport  United States Virgin Islands     520.109.2482x26052
# 9998  Camachochester                         Niger       001-465-242-9979
# 9999      Sparkstown                       Tunisia  +1-889-682-9490x65400
#
#                     Phone 2                                 Email  \
# ...

# %%
df.shape
# Out:
# (10000, 12)

# %%
df = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\it services\\IT Services\\customers-10000.csv")

# %%
df_csv= pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\it services\\IT Services\\customers-10000.csv",skiprows=3)

# %%
df_csv.head()
# Out:
#    3  67DAB15Ebe4BE4a    Briana   Andersen               Irwin-Oneal  \
# 0  4  6d350C5E5eDB4EE     Patty      Ponce          Richardson Group
# 1  5  5820deAdCF23EFe  Kathleen  Mccormick              Carson-Burch
# 2  6  E1CDEaC63fDd5aA    Trevor        Lee              Maddox Group
# 3  7  3e1187fCcebC8d2    Mathew    Hoffman  Bender, Pittman and Kidd
# 4  8  47C5cEE243c9A7b     Glenn    Wiggins              Glenn-Harvey
#
#           East Jordan                        Nepal             8352752061  \
# 0    East Kristintown     Northern Mariana Islands           302.398.3833
# 1         Andresmouth                        Macao  001-184-153-9683x1497
# 2  Lake Madelineburgh                      Senegal   +1-134-348-0265x9132
# 3          West Ralph                   Uzbekistan           842.380.1168
# 4          Ambershire  Falkland Islands (Malvinas)       245-207-5608x563
#
#          (567)135-1918     haleybraun@blevins-sexton.com  22-03-2022  \
# ...

# %%
import pandas as pd

# %%
excel=pd.read_excel("C:\\Users\\Admin\\OneDrive\\Desktop\\it services\\IT Services\\IT_Services_Task_Sheet.xlsx", sheet_name='Sheet1')

# %%
df_csv.head()
# Out:
#    3  67DAB15Ebe4BE4a    Briana   Andersen               Irwin-Oneal  \
# 0  4  6d350C5E5eDB4EE     Patty      Ponce          Richardson Group
# 1  5  5820deAdCF23EFe  Kathleen  Mccormick              Carson-Burch
# 2  6  E1CDEaC63fDd5aA    Trevor        Lee              Maddox Group
# 3  7  3e1187fCcebC8d2    Mathew    Hoffman  Bender, Pittman and Kidd
# 4  8  47C5cEE243c9A7b     Glenn    Wiggins              Glenn-Harvey
#
#           East Jordan                        Nepal             8352752061  \
# 0    East Kristintown     Northern Mariana Islands           302.398.3833
# 1         Andresmouth                        Macao  001-184-153-9683x1497
# 2  Lake Madelineburgh                      Senegal   +1-134-348-0265x9132
# 3          West Ralph                   Uzbekistan           842.380.1168
# 4          Ambershire  Falkland Islands (Malvinas)       245-207-5608x563
#
#          (567)135-1918     haleybraun@blevins-sexton.com  22-03-2022  \
# ...

# %%
#display last 6 sell
df.tail(6)
# Out:
#       Index      Customer Id First Name   Last Name            Company  \
# 9994   9995  D7E40cCBde64d59        Kim       Yoder  Carpenter-Fleming
# 9995   9996  DD0caa06ebf217c     Meghan       Cline     Richardson LLC
# 9996   9997  C1C62ff90D0AfED   Jeremiah        Pena        Hodge-Nixon
# 9997   9998  2EfAa6Fe435A7DA      Peggy         Key           Vang LLC
# 9998   9999  5dB06C3Fab5CCCb       Evan    Humphrey          Gould Ltd
# 9999  10000  9903e8fF4D8Ff0F    Melissa  Montgomery       Burns-Holden
#
#                    City                       Country                Phone 1  \
# 9994  Lake Lawrenceview                       Armenia      667.966.2755x2648
# 9995         Petersport                 Cote d'Ivoire   001-270-136-4738x419
# 9996         Briggsport                       Namibia   +1-531-494-7645x4844
# 9997     West Joyceport  United States Virgin Islands     520.109.2482x26052
# 9998     Camachochester                         Niger       001-465-242-9979
# ...

# %%
# Display random 7 sample rows
df.sample(7)
# Out:
#       Index      Customer Id First Name Last Name                    Company  \
# 5591   5592  87bFb2e9d6d0A3d      Laura   Swanson              Glenn-Parrish
# 6012   6013  eD30cdb4C0cac13     Latoya     Olson  Long, Odonnell and Zavala
# 7107   7108  91f00bF306FfAfA  Johnathan   Acevedo             Richardson PLC
# 1285   1286  12f9Ee9f736Ae49      Julie      Bean             Haney and Sons
# 466     467  ee24eBb8cb1CeC8     Alisha    Brooks               Costa-Burton
# 4957   4958  cdf15BD9318F5bf    Cynthia     Mckee                   Peck LLC
# 9907   9908  9E6Ee7D48AADDD6    Candace   Santana            Blankenship Inc
#
#                 City   Country            Phone 1                Phone 2  \
# 5591      Shortmouth    Mexico       222.879.3008  001-668-633-1870x3253
# 6012    Lake Loretta     Congo  313-376-7621x8994      134.526.0827x7896
# 7107       New Cindy      Guam         8550090400  001-829-148-2793x9233
# ...

# %%
#display first 4 rows of Briana , Napal and East Jardan column
df[['Index','Company']].head(4)
# Out:
#    Index                   Company
# 0      1              Mosley-David
# 1      2  Horn, Shepard and Watson
# 2      3               Irwin-Oneal
# 3      4          Richardson Group

# %%
#display last 10 rows of Briana , Nepal ,East Jordan column
df[['Website','Subscription Date','Email']].head(4)
# Out:
#                          Website Subscription Date  \
# 0        http://www.escobar.org/        26-08-2020
# 1       https://tyler-pugh.info/        27-04-2020
# 2     https://www.mack-bell.net/        22-03-2022
# 3  https://delacruz-freeman.org/        02-07-2020
#
#                            Email
# 0   urangel@espinoza-francis.net
# 1        xreese@hall-donovan.com
# 2  haleybraun@blevins-sexton.com
# 3           hohailey@anthony.com

# %%
# for display 2nd to 6th rows
df[2:7]
# Out:
#    Index      Customer Id First Name  Last Name                   Company  \
# 2      3  67DAB15Ebe4BE4a     Briana   Andersen               Irwin-Oneal
# 3      4  6d350C5E5eDB4EE      Patty      Ponce          Richardson Group
# 4      5  5820deAdCF23EFe   Kathleen  Mccormick              Carson-Burch
# 5      6  E1CDEaC63fDd5aA     Trevor        Lee              Maddox Group
# 6      7  3e1187fCcebC8d2     Mathew    Hoffman  Bender, Pittman and Kidd
#
#                  City                   Country                Phone 1  \
# 2         East Jordan                     Nepal             8352752061
# 3    East Kristintown  Northern Mariana Islands           302.398.3833
# 4         Andresmouth                     Macao  001-184-153-9683x1497
# 5  Lake Madelineburgh                   Senegal   +1-134-348-0265x9132
# 6          West Ralph                Uzbekistan           842.380.1168
#
#                Phone 2                             Email Subscription Date  \
# ...

# %%
# for display starting to 10 th 
df[:11]
# Out:
#     Index      Customer Id First Name  Last Name                      Company  \
# 0       1  EB54EF1154C3A78    Heather   Callahan                 Mosley-David
# 1       2  10dAcafEBbA5FcA   Kristina    Ferrell     Horn, Shepard and Watson
# 2       3  67DAB15Ebe4BE4a     Briana   Andersen                  Irwin-Oneal
# 3       4  6d350C5E5eDB4EE      Patty      Ponce             Richardson Group
# 4       5  5820deAdCF23EFe   Kathleen  Mccormick                 Carson-Burch
# 5       6  E1CDEaC63fDd5aA     Trevor        Lee                 Maddox Group
# 6       7  3e1187fCcebC8d2     Mathew    Hoffman     Bender, Pittman and Kidd
# 7       8  47C5cEE243c9A7b      Glenn    Wiggins                 Glenn-Harvey
# 8       9  cacaD68a5e4BF4b      Bruce      Payne      Arroyo, Cain and Hudson
# 9      10  436b9c41cfb1fa3    Brendan     Franco  Schaefer, Blair and Shaffer
# 10     11  9653ca648e2E414     Martin    Hawkins                    Lopez Inc
#
# ...

# %%
# for display last 2 rows
df[-2:]
# Out:
#       Index      Customer Id First Name   Last Name       Company  \
# 9998   9999  5dB06C3Fab5CCCb       Evan    Humphrey     Gould Ltd
# 9999  10000  9903e8fF4D8Ff0F    Melissa  Montgomery  Burns-Holden
#
#                 City  Country                Phone 1               Phone 2  \
# 9998  Camachochester    Niger       001-465-242-9979  001-639-955-2116x751
# 9999      Sparkstown  Tunisia  +1-889-682-9490x65400    423.632.2539x98740
#
#                                      Email Subscription Date  \
# 9998  velazquezjessica@villegas-wilcox.com        14-04-2020
# 9999               ngallagher@martinez.com        27-06-2020
#
#                       Website
# 9998  https://www.payne.info/
# 9999        http://nixon.net/

# %%
# create new df_col dataframe from df.copy() method
df_col=df.copy()

# %%
df_col
# Out:
#       Index      Customer Id First Name   Last Name                   Company  \
# 0         1  EB54EF1154C3A78    Heather    Callahan              Mosley-David
# 1         2  10dAcafEBbA5FcA   Kristina     Ferrell  Horn, Shepard and Watson
# 2         3  67DAB15Ebe4BE4a     Briana    Andersen               Irwin-Oneal
# 3         4  6d350C5E5eDB4EE      Patty       Ponce          Richardson Group
# 4         5  5820deAdCF23EFe   Kathleen   Mccormick              Carson-Burch
# ...     ...              ...        ...         ...                       ...
# 9995   9996  DD0caa06ebf217c     Meghan       Cline            Richardson LLC
# 9996   9997  C1C62ff90D0AfED   Jeremiah        Pena               Hodge-Nixon
# 9997   9998  2EfAa6Fe435A7DA      Peggy         Key                  Vang LLC
# 9998   9999  5dB06C3Fab5CCCb       Evan    Humphrey                 Gould Ltd
# 9999  10000  9903e8fF4D8Ff0F    Melissa  Montgomery              Burns-Holden
#
# ...

# %%
df.drop(columns=['Phone 1'], inplace=True)
df
# Out:
#       Index      Customer Id First Name   Last Name                   Company  \
# 0         1  EB54EF1154C3A78    Heather    Callahan              Mosley-David
# 1         2  10dAcafEBbA5FcA   Kristina     Ferrell  Horn, Shepard and Watson
# 2         3  67DAB15Ebe4BE4a     Briana    Andersen               Irwin-Oneal
# 3         4  6d350C5E5eDB4EE      Patty       Ponce          Richardson Group
# 4         5  5820deAdCF23EFe   Kathleen   Mccormick              Carson-Burch
# ...     ...              ...        ...         ...                       ...
# 9995   9996  DD0caa06ebf217c     Meghan       Cline            Richardson LLC
# 9996   9997  C1C62ff90D0AfED   Jeremiah        Pena               Hodge-Nixon
# 9997   9998  2EfAa6Fe435A7DA      Peggy         Key                  Vang LLC
# 9998   9999  5dB06C3Fab5CCCb       Evan    Humphrey                 Gould Ltd
# 9999  10000  9903e8fF4D8Ff0F    Melissa  Montgomery              Burns-Holden
#
# ...

# %%
df_col.loc[df_col["Phone 1"] == 9087675544, "Phone 1"] = 7788996654
df_col.loc[df_col["Phone 1"] == 9966332211, "Phone 2"] = 77441123

# %%
print(df_col.columns)
# Out:
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#        'Website'],
#       dtype='object')
